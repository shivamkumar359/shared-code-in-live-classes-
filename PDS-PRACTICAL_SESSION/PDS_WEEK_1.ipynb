# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamkumar359/shared-code-in-live-classes-/blob/main/PDS-PRACTICAL_SESSION/PDS_DAYI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
# 0. WARM-UP
print("I am ready for Python!")
# Out:
# I am ready for Python!

# %%
print("Learning Python is Easy!")
print("Python", "Programming", sep=" - ")
# Out:
# Learning Python is Easy!
# Python - Programming

# %%
print("Hello", end=" ")
print("World")
# Out:
# Hello World

# %%
# 2. LITERALS
# ------------------------------------------------------------
integer_literal = 100
float_literal = 99.95
string_literal = "Python"
boolean_literal = True

# %%
print("Integer Literal :", integer_literal)
print("Float Literal   :", float_literal)
print("String Literal  :", string_literal)
print("Boolean Literal :", boolean_literal)
# Out:
# Integer Literal : 100
# Float Literal   : 99.95
# String Literal  : Python
# Boolean Literal : True

# %% [markdown]
# # **# 3. DATA TYPES**

# %%
print("Data Types")
print(type(integer_literal))
print(type(float_literal))
print(type(string_literal))
print(type(boolean_literal))
# Out:
# Data Types
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **# 4. VARIABLES**

# %%
student_name = "John"
age = 22
salary = 55000

# %%
print("Student Name :", student_name)
print("Age :", age)
print("Salary :", salary)
# Out:
# Student Name : John
# Age : 22
# Salary : 55000

# %%
# 5. USER INPUT
name = input("Enter your name : ")
marks = float(input("Enter your marks : "))

print("Welcome", name)
print("Marks =", marks)
# Out:
# Enter your name : Mithun
# Enter your marks : 66
# Welcome Mithun
# Marks = 66.0

# %%
# 6. FUNCTIONS-User Defined
# ------------------------------------------------------------
def greet():
    print("Welcome to Python Functions")

# %%
greet()
# Out:
# Welcome to Python Functions

# %%
# 7. FUNCTION PARAMETERS
# ------------------------------------------------------------
def add(a, b):
    print("Addition =", a + b)

# %%
add(15, 25)
# Out:
# Addition = 40

# %%
# 7. FUNCTION PARAMETERS-ExampleII
def sos(a, b):
    print("sos =", a*a + b*b)

# %%
sos(5, 2)
# Out:
# sos = 29

# %%
# 8. DEFAULT PARAMETERS
# ------------------------------------------------------------
def welcome(name="Guest"):
    print("Hello", name)

# %%
welcome()
# Out:
# Hello Guest

# %%
welcome("Mithun")
# Out:
# Hello Mithun
